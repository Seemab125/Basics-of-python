# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
df = df.loc[:, ~df.columns.duplicated()]
df = df.drop_duplicates()


df = df.dropna(axis=1, how='all')
df = df.dropna(axis=0, how='all')


df=pd.read_csv('Cat_human_New.csv')
df
# Out:
#            Color Eye_color  Height  Legs Moustache Tail     Weight  label
# 0          black     black    5.14     2        No   No  70.000000  human
# 1     dark_brown     brown    6.80     2        No   No  64.400000  human
# 2    light_brown     brown    5.00     2       Yes   No  64.800000  human
# 3    light_brown      blue    5.90     2        No   No  78.800000  human
# 4    light_brown      blue    6.56     2        No   No  73.200000  human
# ..           ...       ...     ...   ...       ...  ...        ...    ...
# 195        brown      gray    1.14     4       Yes  Yes   2.304511    Cat
# 196        white    yellow    1.39     4       Yes  Yes   5.687970    Cat
# 197        white     black    0.53     4       Yes  Yes   6.364662    Cat
# 198        brown     green    1.03     4       Yes  Yes   6.590226    Cat
# 199  brown_white      blue    0.83     4       Yes  Yes   7.868421    Cat
#
# [200 rows x 8 columns]

# %%
#  Task1:
#        Read given cat_dog.csv file into dataframe. Display different scatterplots between
#        all features.
#         Each column visualization
 
import pandas as pd
import matplotlib.pyplot as plt


df = pd.read_csv('Cat_human_New.csv')
plt.scatter(df['label'], df['Color'])
plt.xlabel('Label')
plt.ylabel('Color')
plt.title('Scatter Plot')
plt.show()

# %%
plt.scatter(df['label'], df['Eye_color'])
plt.xlabel('Label')
plt.ylabel('Eye_color')
plt.title('Scatter Plot')
plt.show()

# %%
plt.scatter(df['label'], df['Height'])
plt.xlabel('Label')
plt.ylabel('Height')
plt.title('Scatter Plot')
plt.show()

# %%
plt.scatter(df['label'], df['Legs'])
plt.xlabel('Label')
plt.ylabel('Legs')
plt.title('Scatter Plot')
plt.show()

# %%
plt.scatter(df['label'], df['Moustache'])
plt.xlabel('Label')
plt.ylabel('Moustache')
plt.title('Scatter Plot')
plt.show()

# %%
plt.scatter(df['label'], df['Tail'])
plt.xlabel('Label')
plt.ylabel('Tail')
plt.title('Scatter Plot')
plt.show()

# %%
plt.scatter(df['label'], df['Weight'])
plt.xlabel('Label')
plt.ylabel('Weight')
plt.title('Scatter Plot')
plt.show()

# %%
#    > Draw box plot
import seaborn as sns


df = pd.read_csv('Cat_human_New.csv')
sns.boxplot(x='label', y='Weight', data=df)
plt.show()
df = pd.read_csv('Cat_human_New.csv')
sns.boxplot(x='label', y='Height', data=df)
plt.show()
df = pd.read_csv('Cat_human_New.csv')
sns.boxplot(x='label', y='Height', data=df)
plt.show()
df = pd.read_csv('Cat_human_New.csv')
sns.boxplot(x='label', y='Legs', data=df)
plt.show()

# %%
#   Draw Line Graph



df = pd.read_csv('Cat_human_New.csv')
df.plot(kind='line')
# Out:
# <Axes: >

# %%
#    Draw Bar Graph

plt.figure(figsize=(30,4))
df = pd.read_csv('Cat_human_New.csv')
df.plot(kind='bar')
# Out:
# <Axes: >

# %%
#  Draw Histogram

df.plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
#   Make Pie chat

R = df['Color'].value_counts()
X=R.index
Y=R.values

plt.pie(Y ,labels=X)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d6127da800>,
# ...
#  [Text(0.8899186877588753, 0.6465637858537406, 'black'),
#   Text(-0.3399187231970732, 1.046162158377023, 'brown'),
#   Text(-1.0999999999999988, -5.149471622296949e-08, 'white'),
#   Text(-0.6465637233635886, -0.8899187331606258, 'dark_brown'),
#   Text(7.724207457870327e-08, -1.0999999999999974, 'light_brown'),
#   Text(0.6465638483438898, -0.88991864235712, 'brown_white'),
#   Text(1.0461621981588753, -0.33991860076110864, 'gray')])

# %%
R = df['Eye_color'].value_counts()
X=R.index
Y=R.values

plt.pie(Y ,labels=X)
# Out:
# ([<matplotlib.patches.Wedge at 0x1d61176afe0>,
# ...
#  [Text(0.8364465755372912, 0.7143928375004461, 'black'),
#   Text(-0.5747483684997868, 0.9379042130765984, 'blue'),
#   Text(-1.0162675251747608, -0.42095168045176784, 'gray'),
#   Text(-0.08630512850696999, -1.0966090574098846, 'brown'),
#   Text(0.6465636817034847, -0.8899187634284575, 'yellow'),
#   Text(1.0461621345079046, -0.3399187966586506, 'green')])

# %%
# Categorize data based on weight condition
cat_count = df[df['Weight'] < 10].shape[0]
human_count = df[df['Weight'] >= 10].shape[0]

# Create labels for the pie chart
labels = ['Cat', 'Human']

# Create data for the pie chart
sizes = [cat_count, human_count]

# Plot the pie chart
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

# Set the title of the pie chart
plt.title('Weight Category Distribution')

# Display the chart
plt.show()

# %%
R = df['Legs'].value_counts()
X=R.index
Y=R.values

plt.pie(Y ,labels=X)
# Out:
# ([<matplotlib.patches.Wedge at 0x262d7994460>,
# ...
#  [Text(6.735557395310444e-17, 1.1, '2'),
#   Text(-2.0206672185931328e-16, -1.1, '4')])

# %%
R = df['Moustache'].value_counts()
X=R.index
Y=R.values

plt.pie(Y ,labels=X)
# Out:
# ([<matplotlib.patches.Wedge at 0x262d79ca6b0>,
# ...
#  [Text(-0.7778174593052023, 0.7778174593052024, 'Yes'),
#   Text(0.7778174593052022, -0.7778174593052025, 'No')])

# %%
R = df['Tail'].value_counts()
X=R.index
Y=R.values

plt.pie(Y ,labels=X)
# Out:
# ([<matplotlib.patches.Wedge at 0x262d7a24d60>,
# ...
#  [Text(6.735557395310444e-17, 1.1, 'No'),
#   Text(-2.0206672185931328e-16, -1.1, 'Yes')])

# %%
#     Draw Heat map

import seaborn as sb

n = df.select_dtypes(include = 'number')
n
correlation= n.corr()
correlation
sb.heatmap(correlation, annot=True ,cmap='coolwarm')
# Out:
# <Axes: >

# %%
#       Write a complete report on this dataset

df = pd.read_csv('Cat_human_New.csv')

report = df.describe()
print('Before cleaning')
print(df)

# Remove duplicate columns
df = df.loc[:, ~df.columns.duplicated()]

# Remove duplicate rows
df = df.drop_duplicates()

# Remove blank columns
df = df.dropna(axis=1, how='all')

# Remove blank rows
df = df.dropna(axis=0, how='all')

# Display the cleaned data
report = df.describe()
print('After cleaning')
print(df)
# Out:
# Before cleaning
#            Color Eye_color  Height  Legs Moustache Tail     Weight  label
# 0          black     black    5.14     2        No   No  70.000000  human
# 1     dark_brown     brown    6.80     2        No   No  64.400000  human
# 2    light_brown     brown    5.00     2       Yes   No  64.800000  human
# 3    light_brown      blue    5.90     2        No   No  78.800000  human
# 4    light_brown      blue    6.56     2        No   No  73.200000  human
# ..           ...       ...     ...   ...       ...  ...        ...    ...
# 195        brown      gray    1.14     4       Yes  Yes   2.304511    Cat
# 196        white    yellow    1.39     4       Yes  Yes   5.687970    Cat
# 197        white     black    0.53     4       Yes  Yes   6.364662    Cat
# 198        brown     green    1.03     4       Yes  Yes   6.590226    Cat
# 199  brown_white      blue    0.83     4       Yes  Yes   7.868421    Cat
#
# [200 rows x 8 columns]
# After cleaning
# ...

# %%
 #  Task2:6
#           Make pandas profiling


# !pip install pandas-profiling
import pandas_profiling as pdp
import pandas as pd



df=pd.read_csv("Cat_human_New.csv")
profile = pdp.ProfileReport(df)
profile.to_file("data_profile.html")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
# Convert each column into row and perform visualization


import pandas as pd
df = pd.read_csv('Cat_human_New.csv')
transposed_df = df.transpose()
print(transposed_df)
# Out:
#              0           1            2            3            4      5    \
# Color      black  dark_brown  light_brown  light_brown  light_brown  brown
# Eye_color  black       brown        brown         blue         blue  brown
# Height      5.14         6.8          5.0          5.9         6.56   5.56
# Legs           2           2            2            2            2      2
# Moustache     No          No          Yes           No           No     No
# Tail          No          No           No           No           No     No
# Weight      70.0        64.4         64.8         78.8         73.2   65.2
# label      human       human        human        human        human  human
#
#              6      7      8           9    ...       190       191       192  \
# Color      black  brown  black  dark_brown  ...     white      gray     brown
# Eye_color   blue   gray  black       brown  ...     black      gray     green
# ...

# %%
#   Perform visualization on numerical data and categorical data separately

# Convert each column into rows for numerical data
numerical_data = df.select_dtypes(include='number')
melted_numerical_data = numerical_data.melt(var_name='Column', value_name='Value')

# Perform visualization on melted numerical data
plt.figure(figsize=(10, 6))
plt.bar(melted_numerical_data['Column'], melted_numerical_data['Value'])
plt.xlabel('Column')
plt.ylabel('Value')
plt.title('Visualization of Numerical Columns')
plt.xticks(rotation=45)
plt.show()

# Convert each column into rows for categorical data
categorical_data = df.select_dtypes(include='object')
melted_categorical_data = categorical_data.melt(var_name='Column', value_name='Value')

# Perform visualization on melted categorical data
plt.figure(figsize=(10, 6))
plt.bar(melted_categorical_data['Column'], melted_categorical_data['Value'])
plt.xlabel('Column')
plt.ylabel('Value')
plt.title('Visualization of Categorical Columns')
plt.xticks(rotation=45)
plt.show()
